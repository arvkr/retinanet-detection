# %%
import pandas as pd
import numpy as np

# %%
ann_orig = pd.read_csv('./orig_anno.csv')

# %%
# ./dataset/clean_resized/0.jpg,125,165,209,201,neck
ann_dict = [{'file_name':'./dataset/clean_resized/0.jpg','x1':125,'y1':165,'x2':209,'y2':201,'body_part':'neck'}]
ann_new = pd.DataFrame(ann_dict)

# %%
ann_orig
# Out:
#     filename  file_size file_attributes  region_count  region_id  \
# 0      0.jpg     103135              {}             3          0
# 1      0.jpg     103135              {}             3          1
# 2      0.jpg     103135              {}             3          2
# 3      1.jpg      90319              {}             3          0
# 4      1.jpg      90319              {}             3          1
# ..       ...        ...             ...           ...        ...
# 369  235.jpg      59439              {}             0          0
# 370  236.jpg      58676              {}             0          0
# 371  237.jpg      68500              {}             0          0
# 372  238.jpg      63089              {}             0          0
# 373  239.jpg      64329              {}             0          0
#
#                                region_shape_attributes  \
# 0    {"name":"rect","x":167,"y":183,"width":84,"hei...
# 1    {"name":"rect","x":178,"y":406,"width":188,"he...
# 2    {"name":"rect","x":151,"y":508,"width":238,"he...
# 3    {"name":"rect","x":163,"y":458,"width":170,"he...
# 4    {"name":"rect","x":197,"y":207,"width":102,"he...
# ..                                                 ...
# 369                                                 {}
# 370                                                 {}
# 371                                                 {}
# 372                                                 {}
# 373                                                 {}
#
#                                      region_attributes
# 0    {"body_part":"neck","gender":"male","body_type...
# 1    {"body_part":"stomach","gender":"male","body_t...
# 2    {"body_part":"hip","gender":"male","body_type"...
# 3    {"body_part":"stomach","gender":"male","body_t...
# 4    {"body_part":"neck","gender":"male","body_type...
# ..                                                 ...
# 369                                                 {}
# 370                                                 {}
# 371                                                 {}
# 372                                                 {}
# 373                                                 {}
#
# [374 rows x 7 columns]

# %%
ann_orig.iloc[0,0]
# Out:
# '0.jpg'

# %%
import ast

# %%
ast.literal_eval(ann_orig.iloc[0,6])['body_part']
# Out:
# 'neck'

# %%
import pandas as pd
import ast

def change_format(left_x,top_y,width,height):
    anno = {}
    anno['x1'] = int(left_x)
    anno['y1'] = int(top_y)
    anno['x2'] = int(left_x + width)
    anno['y2'] = int(top_y + height)

    return anno

orig_ann = pd.read_csv('./orig_anno.csv')
new_ann_list = []
for i in range(206):
    ann_dict = {}
    ann_dict['file_name'] = './dataset/clean_resized/' + orig_ann.iloc[i,0]
    lx = ast.literal_eval(orig_ann.iloc[i,5])['x']
    ty = ast.literal_eval(orig_ann.iloc[i,5])['y']
    w = ast.literal_eval(orig_ann.iloc[i,5])['width']
    h = ast.literal_eval(orig_ann.iloc[i,5])['height']
    anno = change_format(lx,ty,w,h)
    ann_dict['x1'] = anno['x1']
    ann_dict['y1'] = anno['y1']
    ann_dict['x2'] = anno['x2']
    ann_dict['y2'] = anno['y2']
    ann_dict['body_part'] = ast.literal_eval(orig_ann.iloc[i,6])['body_part']
    new_ann_list.append(ann_dict)

new_ann = pd.DataFrame(new_ann_list)
new_ann.to_csv('csv_annotations.csv', index = False)

# %%
new_ann.to_csv('csv_annotations.csv', index = False)

# %%
orig_ann.iloc[1,5]
# Out:
# '{"name":"rect","x":178,"y":406,"width":188,"height":81}'

# %%
from sklearn.utils import shuffle

# %%
shuffle(new_ann_list, random_state = 1)
# Out:
# [{'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 294,
#   'y1': 160,
#   'x2': 352,
#   'y2': 190,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/35.jpg',
#   'x1': 183,
#   'y1': 160,
#   'x2': 265,
#   'y2': 202,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/55.jpg',
#   'x1': 201,
#   'y1': 201,
#   'x2': 267,
#   'y2': 222,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/16.jpg',
#   'x1': 372,
#   'y1': 335,
#   'x2': 474,
#   'y2': 372,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/15.jpg',
#   'x1': 244,
#   'y1': 400,
#   'x2': 408,
#   'y2': 455,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/25.jpg',
#   'x1': 205,
#   'y1': 188,
#   'x2': 307,
#   'y2': 269,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/35.jpg',
#   'x1': 103,
#   'y1': 440,
#   'x2': 336,
#   'y2': 472,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/7.jpg',
#   'x1': 169,
#   'y1': 374,
#   'x2': 304,
#   'y2': 422,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/55.jpg',
#   'x1': 143,
#   'y1': 396,
#   'x2': 330,
#   'y2': 443,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/23.jpg',
#   'x1': 266,
#   'y1': 222,
#   'x2': 328,
#   'y2': 242,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/1.jpg',
#   'x1': 197,
#   'y1': 207,
#   'x2': 299,
#   'y2': 253,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/62.jpg',
#   'x1': 256,
#   'y1': 326,
#   'x2': 410,
#   'y2': 369,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/52.jpg',
#   'x1': 125,
#   'y1': 480,
#   'x2': 339,
#   'y2': 530,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/14.jpg',
#   'x1': 204,
#   'y1': 290,
#   'x2': 309,
#   'y2': 329,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/11.jpg',
#   'x1': 162,
#   'y1': 383,
#   'x2': 302,
#   'y2': 419,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/62.jpg',
#   'x1': 312,
#   'y1': 117,
#   'x2': 363,
#   'y2': 141,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/67.jpg',
#   'x1': 318,
#   'y1': 97,
#   'x2': 371,
#   'y2': 134,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/12.jpg',
#   'x1': 129,
#   'y1': 547,
#   'x2': 364,
#   'y2': 606,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 5,
#   'y1': 356,
#   'x2': 128,
#   'y2': 380,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/66.jpg',
#   'x1': 219,
#   'y1': 376,
#   'x2': 393,
#   'y2': 416,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/63.jpg',
#   'x1': 306,
#   'y1': 153,
#   'x2': 368,
#   'y2': 179,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/12.jpg',
#   'x1': 207,
#   'y1': 172,
#   'x2': 291,
#   'y2': 222,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/4.jpg',
#   'x1': 38,
#   'y1': 583,
#   'x2': 317,
#   'y2': 635,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/43.jpg',
#   'x1': 115,
#   'y1': 365,
#   'x2': 322,
#   'y2': 430,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 142,
#   'y1': 264,
#   'x2': 194,
#   'y2': 285,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/13.jpg',
#   'x1': 278,
#   'y1': 121,
#   'x2': 339,
#   'y2': 153,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/30.jpg',
#   'x1': 134,
#   'y1': 437,
#   'x2': 335,
#   'y2': 489,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 347,
#   'y1': 315,
#   'x2': 437,
#   'y2': 338,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/44.jpg',
#   'x1': 227,
#   'y1': 144,
#   'x2': 265,
#   'y2': 161,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/13.jpg',
#   'x1': 227,
#   'y1': 296,
#   'x2': 361,
#   'y2': 345,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/54.jpg',
#   'x1': 201,
#   'y1': 257,
#   'x2': 314,
#   'y2': 295,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/11.jpg',
#   'x1': 190,
#   'y1': 150,
#   'x2': 255,
#   'y2': 187,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/6.jpg',
#   'x1': 163,
#   'y1': 291,
#   'x2': 271,
#   'y2': 323,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/47.jpg',
#   'x1': 114,
#   'y1': 266,
#   'x2': 262,
#   'y2': 300,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/42.jpg',
#   'x1': 255,
#   'y1': 323,
#   'x2': 406,
#   'y2': 359,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 351,
#   'y1': 279,
#   'x2': 421,
#   'y2': 307,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/10.jpg',
#   'x1': 198,
#   'y1': 379,
#   'x2': 349,
#   'y2': 417,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/17.jpg',
#   'x1': 111,
#   'y1': 525,
#   'x2': 343,
#   'y2': 593,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/21.jpg',
#   'x1': 68,
#   'y1': 539,
#   'x2': 337,
#   'y2': 609,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/71.jpg',
#   'x1': 111,
#   'y1': 163,
#   'x2': 199,
#   'y2': 195,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/66.jpg',
#   'x1': 232,
#   'y1': 305,
#   'x2': 377,
#   'y2': 347,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/39.jpg',
#   'x1': 172,
#   'y1': 321,
#   'x2': 308,
#   'y2': 375,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/32.jpg',
#   'x1': 236,
#   'y1': 393,
#   'x2': 409,
#   'y2': 450,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/53.jpg',
#   'x1': 89,
#   'y1': 499,
#   'x2': 346,
#   'y2': 552,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/52.jpg',
#   'x1': 196,
#   'y1': 164,
#   'x2': 266,
#   'y2': 192,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/34.jpg',
#   'x1': 184,
#   'y1': 428,
#   'x2': 332,
#   'y2': 473,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/27.jpg',
#   'x1': 217,
#   'y1': 286,
#   'x2': 288,
#   'y2': 309,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/19.jpg',
#   'x1': 192,
#   'y1': 412,
#   'x2': 390,
#   'y2': 495,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/43.jpg',
#   'x1': 184,
#   'y1': 22,
#   'x2': 268,
#   'y2': 47,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/37.jpg',
#   'x1': 146,
#   'y1': 491,
#   'x2': 345,
#   'y2': 538,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/26.jpg',
#   'x1': 288,
#   'y1': 45,
#   'x2': 355,
#   'y2': 80,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/39.jpg',
#   'x1': 190,
#   'y1': 148,
#   'x2': 264,
#   'y2': 173,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/6.jpg',
#   'x1': 189,
#   'y1': 146,
#   'x2': 231,
#   'y2': 163,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/59.jpg',
#   'x1': 256,
#   'y1': 355,
#   'x2': 398,
#   'y2': 408,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/22.jpg',
#   'x1': 301,
#   'y1': 162,
#   'x2': 371,
#   'y2': 199,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/7.jpg',
#   'x1': 146,
#   'y1': 438,
#   'x2': 323,
#   'y2': 475,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/67.jpg',
#   'x1': 234,
#   'y1': 386,
#   'x2': 429,
#   'y2': 417,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/14.jpg',
#   'x1': 197,
#   'y1': 349,
#   'x2': 317,
#   'y2': 384,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/40.jpg',
#   'x1': 168,
#   'y1': 287,
#   'x2': 450,
#   'y2': 373,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/60.jpg',
#   'x1': 197,
#   'y1': 161,
#   'x2': 277,
#   'y2': 188,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/21.jpg',
#   'x1': 144,
#   'y1': 167,
#   'x2': 235,
#   'y2': 212,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 251,
#   'y1': 285,
#   'x2': 386,
#   'y2': 321,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/45.jpg',
#   'x1': 256,
#   'y1': 184,
#   'x2': 296,
#   'y2': 213,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 386,
#   'y1': 345,
#   'x2': 521,
#   'y2': 364,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/56.jpg',
#   'x1': 321,
#   'y1': 53,
#   'x2': 399,
#   'y2': 110,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/20.jpg',
#   'x1': 203,
#   'y1': 113,
#   'x2': 250,
#   'y2': 132,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/34.jpg',
#   'x1': 196,
#   'y1': 213,
#   'x2': 265,
#   'y2': 243,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/69.jpg',
#   'x1': 136,
#   'y1': 505,
#   'x2': 339,
#   'y2': 546,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/38.jpg',
#   'x1': 202,
#   'y1': 188,
#   'x2': 283,
#   'y2': 215,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/48.jpg',
#   'x1': 305,
#   'y1': 139,
#   'x2': 370,
#   'y2': 166,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/16.jpg',
#   'x1': 141,
#   'y1': 200,
#   'x2': 205,
#   'y2': 231,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/7.jpg',
#   'x1': 176,
#   'y1': 168,
#   'x2': 241,
#   'y2': 196,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/1.jpg',
#   'x1': 123,
#   'y1': 585,
#   'x2': 362,
#   'y2': 630,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/54.jpg',
#   'x1': 188,
#   'y1': 300,
#   'x2': 327,
#   'y2': 330,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/70.jpg',
#   'x1': 251,
#   'y1': 161,
#   'x2': 310,
#   'y2': 192,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/18.jpg',
#   'x1': 292,
#   'y1': 118,
#   'x2': 332,
#   'y2': 143,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/60.jpg',
#   'x1': 141,
#   'y1': 413,
#   'x2': 325,
#   'y2': 462,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/24.jpg',
#   'x1': 141,
#   'y1': 459,
#   'x2': 327,
#   'y2': 507,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/42.jpg',
#   'x1': 311,
#   'y1': 120,
#   'x2': 364,
#   'y2': 148,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/20.jpg',
#   'x1': 177,
#   'y1': 239,
#   'x2': 279,
#   'y2': 281,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/33.jpg',
#   'x1': 96,
#   'y1': 393,
#   'x2': 318,
#   'y2': 449,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/44.jpg',
#   'x1': 195,
#   'y1': 290,
#   'x2': 295,
#   'y2': 319,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/32.jpg',
#   'x1': 266,
#   'y1': 157,
#   'x2': 352,
#   'y2': 197,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/62.jpg',
#   'x1': 281,
#   'y1': 278,
#   'x2': 406,
#   'y2': 312,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/45.jpg',
#   'x1': 153,
#   'y1': 371,
#   'x2': 319,
#   'y2': 414,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/5.jpg',
#   'x1': 228,
#   'y1': 97,
#   'x2': 360,
#   'y2': 154,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/46.jpg',
#   'x1': 465,
#   'y1': 253,
#   'x2': 616,
#   'y2': 293,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/37.jpg',
#   'x1': 221,
#   'y1': 210,
#   'x2': 304,
#   'y2': 244,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/69.jpg',
#   'x1': 161,
#   'y1': 400,
#   'x2': 318,
#   'y2': 444,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/58.jpg',
#   'x1': 307,
#   'y1': 191,
#   'x2': 366,
#   'y2': 211,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/36.jpg',
#   'x1': 249,
#   'y1': 152,
#   'x2': 284,
#   'y2': 195,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 437,
#   'y1': 353,
#   'x2': 519,
#   'y2': 406,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/71.jpg',
#   'x1': 77,
#   'y1': 482,
#   'x2': 274,
#   'y2': 527,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/68.jpg',
#   'x1': 221,
#   'y1': 311,
#   'x2': 373,
#   'y2': 340,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/5.jpg',
#   'x1': 147,
#   'y1': 358,
#   'x2': 377,
#   'y2': 428,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/30.jpg',
#   'x1': 234,
#   'y1': 154,
#   'x2': 314,
#   'y2': 190,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/50.jpg',
#   'x1': 159,
#   'y1': 297,
#   'x2': 304,
#   'y2': 320,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 374,
#   'y1': 173,
#   'x2': 401,
#   'y2': 188,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/17.jpg',
#   'x1': 269,
#   'y1': 156,
#   'x2': 350,
#   'y2': 194,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/39.jpg',
#   'x1': 149,
#   'y1': 392,
#   'x2': 318,
#   'y2': 444,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/13.jpg',
#   'x1': 198,
#   'y1': 366,
#   'x2': 382,
#   'y2': 408,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/60.jpg',
#   'x1': 115,
#   'y1': 482,
#   'x2': 334,
#   'y2': 536,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/69.jpg',
#   'x1': 190,
#   'y1': 171,
#   'x2': 269,
#   'y2': 187,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/57.jpg',
#   'x1': 87,
#   'y1': 442,
#   'x2': 294,
#   'y2': 483,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/41.jpg',
#   'x1': 221,
#   'y1': 369,
#   'x2': 323,
#   'y2': 420,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/55.jpg',
#   'x1': 127,
#   'y1': 467,
#   'x2': 357,
#   'y2': 507,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/71.jpg',
#   'x1': 84,
#   'y1': 392,
#   'x2': 266,
#   'y2': 422,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/43.jpg',
#   'x1': 121,
#   'y1': 285,
#   'x2': 289,
#   'y2': 334,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 7,
#   'y1': 304,
#   'x2': 145,
#   'y2': 341,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/28.jpg',
#   'x1': 251,
#   'y1': 216,
#   'x2': 634,
#   'y2': 354,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/8.jpg',
#   'x1': 284,
#   'y1': 235,
#   'x2': 387,
#   'y2': 272,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/33.jpg',
#   'x1': 158,
#   'y1': 70,
#   'x2': 217,
#   'y2': 131,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/57.jpg',
#   'x1': 94,
#   'y1': 377,
#   'x2': 279,
#   'y2': 420,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/0.jpg',
#   'x1': 151,
#   'y1': 508,
#   'x2': 389,
#   'y2': 578,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/26.jpg',
#   'x1': 259,
#   'y1': 223,
#   'x2': 396,
#   'y2': 271,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/31.jpg',
#   'x1': 86,
#   'y1': 237,
#   'x2': 171,
#   'y2': 272,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 142,
#   'y1': 288,
#   'x2': 201,
#   'y2': 309,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/2.jpg',
#   'x1': 98,
#   'y1': 318,
#   'x2': 200,
#   'y2': 359,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/61.jpg',
#   'x1': 206,
#   'y1': 143,
#   'x2': 276,
#   'y2': 177,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/0.jpg',
#   'x1': 167,
#   'y1': 183,
#   'x2': 251,
#   'y2': 219,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/58.jpg',
#   'x1': 236,
#   'y1': 388,
#   'x2': 407,
#   'y2': 438,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 57,
#   'y1': 342,
#   'x2': 198,
#   'y2': 389,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/41.jpg',
#   'x1': 215,
#   'y1': 443,
#   'x2': 372,
#   'y2': 475,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/24.jpg',
#   'x1': 159,
#   'y1': 380,
#   'x2': 301,
#   'y2': 442,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/20.jpg',
#   'x1': 166,
#   'y1': 297,
#   'x2': 284,
#   'y2': 344,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/70.jpg',
#   'x1': 173,
#   'y1': 376,
#   'x2': 317,
#   'y2': 415,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/31.jpg',
#   'x1': 408,
#   'y1': 291,
#   'x2': 613,
#   'y2': 343,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/53.jpg',
#   'x1': 111,
#   'y1': 410,
#   'x2': 321,
#   'y2': 466,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/17.jpg',
#   'x1': 127,
#   'y1': 437,
#   'x2': 299,
#   'y2': 515,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/27.jpg',
#   'x1': 202,
#   'y1': 317,
#   'x2': 299,
#   'y2': 338,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/33.jpg',
#   'x1': 119,
#   'y1': 301,
#   'x2': 291,
#   'y2': 362,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/59.jpg',
#   'x1': 225,
#   'y1': 429,
#   'x2': 408,
#   'y2': 479,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/31.jpg',
#   'x1': 429,
#   'y1': 205,
#   'x2': 590,
#   'y2': 266,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/61.jpg',
#   'x1': 103,
#   'y1': 434,
#   'x2': 326,
#   'y2': 491,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/4.jpg',
#   'x1': 173,
#   'y1': 213,
#   'x2': 315,
#   'y2': 271,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/12.jpg',
#   'x1': 157,
#   'y1': 445,
#   'x2': 335,
#   'y2': 495,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/49.jpg',
#   'x1': 74,
#   'y1': 548,
#   'x2': 374,
#   'y2': 626,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/30.jpg',
#   'x1': 174,
#   'y1': 348,
#   'x2': 326,
#   'y2': 420,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/59.jpg',
#   'x1': 299,
#   'y1': 167,
#   'x2': 367,
#   'y2': 192,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/36.jpg',
#   'x1': 202,
#   'y1': 337,
#   'x2': 345,
#   'y2': 371,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/45.jpg',
#   'x1': 144,
#   'y1': 417,
#   'x2': 330,
#   'y2': 469,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/9.jpg',
#   'x1': 241,
#   'y1': 277,
#   'x2': 333,
#   'y2': 314,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/46.jpg',
#   'x1': 490,
#   'y1': 65,
#   'x2': 562,
#   'y2': 96,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/3.jpg',
#   'x1': 327,
#   'y1': 384,
#   'x2': 479,
#   'y2': 429,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 395,
#   'y1': 308,
#   'x2': 521,
#   'y2': 339,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/38.jpg',
#   'x1': 89,
#   'y1': 413,
#   'x2': 383,
#   'y2': 498,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 156,
#   'y1': 169,
#   'x2': 180,
#   'y2': 181,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/49.jpg',
#   'x1': 180,
#   'y1': 230,
#   'x2': 290,
#   'y2': 266,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/41.jpg',
#   'x1': 270,
#   'y1': 191,
#   'x2': 312,
#   'y2': 228,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/68.jpg',
#   'x1': 279,
#   'y1': 110,
#   'x2': 353,
#   'y2': 141,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/24.jpg',
#   'x1': 157,
#   'y1': 167,
#   'x2': 230,
#   'y2': 205,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/6.jpg',
#   'x1': 178,
#   'y1': 246,
#   'x2': 259,
#   'y2': 275,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/16.jpg',
#   'x1': 397,
#   'y1': 188,
#   'x2': 454,
#   'y2': 210,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/61.jpg',
#   'x1': 144,
#   'y1': 358,
#   'x2': 309,
#   'y2': 411,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/40.jpg',
#   'x1': 259,
#   'y1': 70,
#   'x2': 370,
#   'y2': 96,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 474,
#   'y1': 167,
#   'x2': 541,
#   'y2': 194,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/19.jpg',
#   'x1': 170,
#   'y1': 536,
#   'x2': 403,
#   'y2': 591,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/10.jpg',
#   'x1': 215,
#   'y1': 318,
#   'x2': 329,
#   'y2': 368,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 134,
#   'y1': 175,
#   'x2': 187,
#   'y2': 213,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/16.jpg',
#   'x1': 136,
#   'y1': 340,
#   'x2': 224,
#   'y2': 370,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/9.jpg',
#   'x1': 253,
#   'y1': 492,
#   'x2': 425,
#   'y2': 545,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/1.jpg',
#   'x1': 163,
#   'y1': 458,
#   'x2': 333,
#   'y2': 555,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/63.jpg',
#   'x1': 242,
#   'y1': 355,
#   'x2': 406,
#   'y2': 400,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/18.jpg',
#   'x1': 265,
#   'y1': 244,
#   'x2': 353,
#   'y2': 281,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/54.jpg',
#   'x1': 234,
#   'y1': 128,
#   'x2': 281,
#   'y2': 146,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/47.jpg',
#   'x1': 108,
#   'y1': 308,
#   'x2': 271,
#   'y2': 340,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/68.jpg',
#   'x1': 211,
#   'y1': 386,
#   'x2': 381,
#   'y2': 429,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/11.jpg',
#   'x1': 147,
#   'y1': 428,
#   'x2': 328,
#   'y2': 477,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/44.jpg',
#   'x1': 210,
#   'y1': 250,
#   'x2': 289,
#   'y2': 281,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/42.jpg',
#   'x1': 280,
#   'y1': 277,
#   'x2': 405,
#   'y2': 311,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 131,
#   'y1': 314,
#   'x2': 250,
#   'y2': 345,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/3.jpg',
#   'x1': 343,
#   'y1': 310,
#   'x2': 470,
#   'y2': 351,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/22.jpg',
#   'x1': 268,
#   'y1': 381,
#   'x2': 431,
#   'y2': 447,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/46.jpg',
#   'x1': 435,
#   'y1': 353,
#   'x2': 639,
#   'y2': 403,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/0.jpg',
#   'x1': 178,
#   'y1': 406,
#   'x2': 366,
#   'y2': 487,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/21.jpg',
#   'x1': 97,
#   'y1': 423,
#   'x2': 295,
#   'y2': 495,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/8.jpg',
#   'x1': 275,
#   'y1': 299,
#   'x2': 405,
#   'y2': 333,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/23.jpg',
#   'x1': 286,
#   'y1': 139,
#   'x2': 309,
#   'y2': 155,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/23.jpg',
#   'x1': 253,
#   'y1': 246,
#   'x2': 337,
#   'y2': 274,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/3.jpg',
#   'x1': 382,
#   'y1': 166,
#   'x2': 438,
#   'y2': 184,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/70.jpg',
#   'x1': 150,
#   'y1': 440,
#   'x2': 326,
#   'y2': 482,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/51.jpg',
#   'x1': 165,
#   'y1': 287,
#   'x2': 312,
#   'y2': 321,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/31.jpg',
#   'x1': 66,
#   'y1': 289,
#   'x2': 185,
#   'y2': 317,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/34.jpg',
#   'x1': 162,
#   'y1': 499,
#   'x2': 342,
#   'y2': 552,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/25.jpg',
#   'x1': 126,
#   'y1': 541,
#   'x2': 347,
#   'y2': 616,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/19.jpg',
#   'x1': 260,
#   'y1': 161,
#   'x2': 339,
#   'y2': 206,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/51.jpg',
#   'x1': 152,
#   'y1': 334,
#   'x2': 314,
#   'y2': 379,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/57.jpg',
#   'x1': 172,
#   'y1': 153,
#   'x2': 249,
#   'y2': 187,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/56.jpg',
#   'x1': 214,
#   'y1': 380,
#   'x2': 435,
#   'y2': 436,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/50.jpg',
#   'x1': 236,
#   'y1': 133,
#   'x2': 268,
#   'y2': 143,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/53.jpg',
#   'x1': 173,
#   'y1': 167,
#   'x2': 255,
#   'y2': 195,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/36.jpg',
#   'x1': 214,
#   'y1': 405,
#   'x2': 370,
#   'y2': 434,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/8.jpg',
#   'x1': 317,
#   'y1': 100,
#   'x2': 370,
#   'y2': 126,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 136,
#   'y1': 273,
#   'x2': 245,
#   'y2': 304,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/10.jpg',
#   'x1': 251,
#   'y1': 144,
#   'x2': 319,
#   'y2': 182,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/48.jpg',
#   'x1': 247,
#   'y1': 350,
#   'x2': 416,
#   'y2': 379,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/26.jpg',
#   'x1': 244,
#   'y1': 295,
#   'x2': 418,
#   'y2': 343,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/47.jpg',
#   'x1': 149,
#   'y1': 116,
#   'x2': 216,
#   'y2': 132,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/52.jpg',
#   'x1': 137,
#   'y1': 401,
#   'x2': 328,
#   'y2': 452,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/67.jpg',
#   'x1': 248,
#   'y1': 337,
#   'x2': 413,
#   'y2': 376,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 253,
#   'y1': 350,
#   'x2': 407,
#   'y2': 402,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/48.jpg',
#   'x1': 268,
#   'y1': 296,
#   'x2': 405,
#   'y2': 339,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/50.jpg',
#   'x1': 170,
#   'y1': 261,
#   'x2': 295,
#   'y2': 282,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/27.jpg',
#   'x1': 248,
#   'y1': 165,
#   'x2': 288,
#   'y2': 190,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/51.jpg',
#   'x1': 230,
#   'y1': 121,
#   'x2': 282,
#   'y2': 146,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/14.jpg',
#   'x1': 208,
#   'y1': 146,
#   'x2': 264,
#   'y2': 169,
#   'body_part': 'neck'}]

# %%
new_ann_list
# Out:
# [{'file_name': './dataset/clean_resized/0.jpg',
#   'x1': 167,
#   'y1': 183,
#   'x2': 251,
#   'y2': 219,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/0.jpg',
#   'x1': 178,
#   'y1': 406,
#   'x2': 366,
#   'y2': 487,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/0.jpg',
#   'x1': 151,
#   'y1': 508,
#   'x2': 389,
#   'y2': 578,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/1.jpg',
#   'x1': 163,
#   'y1': 458,
#   'x2': 333,
#   'y2': 555,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/1.jpg',
#   'x1': 197,
#   'y1': 207,
#   'x2': 299,
#   'y2': 253,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/1.jpg',
#   'x1': 123,
#   'y1': 585,
#   'x2': 362,
#   'y2': 630,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/2.jpg',
#   'x1': 98,
#   'y1': 318,
#   'x2': 200,
#   'y2': 359,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/3.jpg',
#   'x1': 382,
#   'y1': 166,
#   'x2': 438,
#   'y2': 184,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/3.jpg',
#   'x1': 343,
#   'y1': 310,
#   'x2': 470,
#   'y2': 351,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/3.jpg',
#   'x1': 327,
#   'y1': 384,
#   'x2': 479,
#   'y2': 429,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/4.jpg',
#   'x1': 173,
#   'y1': 213,
#   'x2': 315,
#   'y2': 271,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/4.jpg',
#   'x1': 38,
#   'y1': 583,
#   'x2': 317,
#   'y2': 635,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/5.jpg',
#   'x1': 228,
#   'y1': 97,
#   'x2': 360,
#   'y2': 154,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/5.jpg',
#   'x1': 147,
#   'y1': 358,
#   'x2': 377,
#   'y2': 428,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/6.jpg',
#   'x1': 189,
#   'y1': 146,
#   'x2': 231,
#   'y2': 163,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/6.jpg',
#   'x1': 178,
#   'y1': 246,
#   'x2': 259,
#   'y2': 275,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/6.jpg',
#   'x1': 163,
#   'y1': 291,
#   'x2': 271,
#   'y2': 323,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/7.jpg',
#   'x1': 176,
#   'y1': 168,
#   'x2': 241,
#   'y2': 196,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/7.jpg',
#   'x1': 169,
#   'y1': 374,
#   'x2': 304,
#   'y2': 422,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/7.jpg',
#   'x1': 146,
#   'y1': 438,
#   'x2': 323,
#   'y2': 475,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/8.jpg',
#   'x1': 317,
#   'y1': 100,
#   'x2': 370,
#   'y2': 126,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/8.jpg',
#   'x1': 284,
#   'y1': 235,
#   'x2': 387,
#   'y2': 272,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/8.jpg',
#   'x1': 275,
#   'y1': 299,
#   'x2': 405,
#   'y2': 333,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/9.jpg',
#   'x1': 241,
#   'y1': 277,
#   'x2': 333,
#   'y2': 314,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/9.jpg',
#   'x1': 253,
#   'y1': 492,
#   'x2': 425,
#   'y2': 545,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/10.jpg',
#   'x1': 251,
#   'y1': 144,
#   'x2': 319,
#   'y2': 182,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/10.jpg',
#   'x1': 215,
#   'y1': 318,
#   'x2': 329,
#   'y2': 368,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/10.jpg',
#   'x1': 198,
#   'y1': 379,
#   'x2': 349,
#   'y2': 417,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/11.jpg',
#   'x1': 190,
#   'y1': 150,
#   'x2': 255,
#   'y2': 187,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/11.jpg',
#   'x1': 162,
#   'y1': 383,
#   'x2': 302,
#   'y2': 419,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/11.jpg',
#   'x1': 147,
#   'y1': 428,
#   'x2': 328,
#   'y2': 477,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/12.jpg',
#   'x1': 207,
#   'y1': 172,
#   'x2': 291,
#   'y2': 222,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/12.jpg',
#   'x1': 157,
#   'y1': 445,
#   'x2': 335,
#   'y2': 495,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/12.jpg',
#   'x1': 129,
#   'y1': 547,
#   'x2': 364,
#   'y2': 606,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/13.jpg',
#   'x1': 278,
#   'y1': 121,
#   'x2': 339,
#   'y2': 153,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/13.jpg',
#   'x1': 227,
#   'y1': 296,
#   'x2': 361,
#   'y2': 345,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/13.jpg',
#   'x1': 198,
#   'y1': 366,
#   'x2': 382,
#   'y2': 408,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/14.jpg',
#   'x1': 208,
#   'y1': 146,
#   'x2': 264,
#   'y2': 169,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/14.jpg',
#   'x1': 204,
#   'y1': 290,
#   'x2': 309,
#   'y2': 329,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/14.jpg',
#   'x1': 197,
#   'y1': 349,
#   'x2': 317,
#   'y2': 384,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/15.jpg',
#   'x1': 244,
#   'y1': 400,
#   'x2': 408,
#   'y2': 455,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/16.jpg',
#   'x1': 397,
#   'y1': 188,
#   'x2': 454,
#   'y2': 210,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/16.jpg',
#   'x1': 141,
#   'y1': 200,
#   'x2': 205,
#   'y2': 231,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/16.jpg',
#   'x1': 136,
#   'y1': 340,
#   'x2': 224,
#   'y2': 370,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/16.jpg',
#   'x1': 372,
#   'y1': 335,
#   'x2': 474,
#   'y2': 372,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/17.jpg',
#   'x1': 269,
#   'y1': 156,
#   'x2': 350,
#   'y2': 194,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/17.jpg',
#   'x1': 127,
#   'y1': 437,
#   'x2': 299,
#   'y2': 515,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/17.jpg',
#   'x1': 111,
#   'y1': 525,
#   'x2': 343,
#   'y2': 593,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/18.jpg',
#   'x1': 292,
#   'y1': 118,
#   'x2': 332,
#   'y2': 143,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/18.jpg',
#   'x1': 265,
#   'y1': 244,
#   'x2': 353,
#   'y2': 281,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/19.jpg',
#   'x1': 260,
#   'y1': 161,
#   'x2': 339,
#   'y2': 206,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/19.jpg',
#   'x1': 192,
#   'y1': 412,
#   'x2': 390,
#   'y2': 495,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/19.jpg',
#   'x1': 170,
#   'y1': 536,
#   'x2': 403,
#   'y2': 591,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/20.jpg',
#   'x1': 203,
#   'y1': 113,
#   'x2': 250,
#   'y2': 132,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/20.jpg',
#   'x1': 177,
#   'y1': 239,
#   'x2': 279,
#   'y2': 281,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/20.jpg',
#   'x1': 166,
#   'y1': 297,
#   'x2': 284,
#   'y2': 344,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/21.jpg',
#   'x1': 144,
#   'y1': 167,
#   'x2': 235,
#   'y2': 212,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/21.jpg',
#   'x1': 97,
#   'y1': 423,
#   'x2': 295,
#   'y2': 495,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/21.jpg',
#   'x1': 68,
#   'y1': 539,
#   'x2': 337,
#   'y2': 609,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/22.jpg',
#   'x1': 301,
#   'y1': 162,
#   'x2': 371,
#   'y2': 199,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/22.jpg',
#   'x1': 268,
#   'y1': 381,
#   'x2': 431,
#   'y2': 447,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/23.jpg',
#   'x1': 286,
#   'y1': 139,
#   'x2': 309,
#   'y2': 155,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/23.jpg',
#   'x1': 266,
#   'y1': 222,
#   'x2': 328,
#   'y2': 242,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/23.jpg',
#   'x1': 253,
#   'y1': 246,
#   'x2': 337,
#   'y2': 274,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/24.jpg',
#   'x1': 157,
#   'y1': 167,
#   'x2': 230,
#   'y2': 205,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/24.jpg',
#   'x1': 159,
#   'y1': 380,
#   'x2': 301,
#   'y2': 442,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/24.jpg',
#   'x1': 141,
#   'y1': 459,
#   'x2': 327,
#   'y2': 507,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/25.jpg',
#   'x1': 205,
#   'y1': 188,
#   'x2': 307,
#   'y2': 269,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/25.jpg',
#   'x1': 126,
#   'y1': 541,
#   'x2': 347,
#   'y2': 616,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/26.jpg',
#   'x1': 288,
#   'y1': 45,
#   'x2': 355,
#   'y2': 80,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/26.jpg',
#   'x1': 259,
#   'y1': 223,
#   'x2': 396,
#   'y2': 271,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/26.jpg',
#   'x1': 244,
#   'y1': 295,
#   'x2': 418,
#   'y2': 343,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/27.jpg',
#   'x1': 248,
#   'y1': 165,
#   'x2': 288,
#   'y2': 190,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/27.jpg',
#   'x1': 217,
#   'y1': 286,
#   'x2': 288,
#   'y2': 309,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/27.jpg',
#   'x1': 202,
#   'y1': 317,
#   'x2': 299,
#   'y2': 338,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/28.jpg',
#   'x1': 251,
#   'y1': 216,
#   'x2': 634,
#   'y2': 354,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 134,
#   'y1': 175,
#   'x2': 187,
#   'y2': 213,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 57,
#   'y1': 342,
#   'x2': 198,
#   'y2': 389,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 294,
#   'y1': 160,
#   'x2': 352,
#   'y2': 190,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 253,
#   'y1': 350,
#   'x2': 407,
#   'y2': 402,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 474,
#   'y1': 167,
#   'x2': 541,
#   'y2': 194,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/29.jpg',
#   'x1': 437,
#   'y1': 353,
#   'x2': 519,
#   'y2': 406,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/30.jpg',
#   'x1': 234,
#   'y1': 154,
#   'x2': 314,
#   'y2': 190,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/30.jpg',
#   'x1': 174,
#   'y1': 348,
#   'x2': 326,
#   'y2': 420,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/30.jpg',
#   'x1': 134,
#   'y1': 437,
#   'x2': 335,
#   'y2': 489,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/31.jpg',
#   'x1': 86,
#   'y1': 237,
#   'x2': 171,
#   'y2': 272,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/31.jpg',
#   'x1': 66,
#   'y1': 289,
#   'x2': 185,
#   'y2': 317,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/31.jpg',
#   'x1': 429,
#   'y1': 205,
#   'x2': 590,
#   'y2': 266,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/31.jpg',
#   'x1': 408,
#   'y1': 291,
#   'x2': 613,
#   'y2': 343,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/32.jpg',
#   'x1': 266,
#   'y1': 157,
#   'x2': 352,
#   'y2': 197,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/32.jpg',
#   'x1': 236,
#   'y1': 393,
#   'x2': 409,
#   'y2': 450,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/33.jpg',
#   'x1': 158,
#   'y1': 70,
#   'x2': 217,
#   'y2': 131,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/33.jpg',
#   'x1': 119,
#   'y1': 301,
#   'x2': 291,
#   'y2': 362,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/33.jpg',
#   'x1': 96,
#   'y1': 393,
#   'x2': 318,
#   'y2': 449,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/34.jpg',
#   'x1': 196,
#   'y1': 213,
#   'x2': 265,
#   'y2': 243,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/34.jpg',
#   'x1': 184,
#   'y1': 428,
#   'x2': 332,
#   'y2': 473,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/34.jpg',
#   'x1': 162,
#   'y1': 499,
#   'x2': 342,
#   'y2': 552,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/35.jpg',
#   'x1': 183,
#   'y1': 160,
#   'x2': 265,
#   'y2': 202,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/35.jpg',
#   'x1': 103,
#   'y1': 440,
#   'x2': 336,
#   'y2': 472,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/36.jpg',
#   'x1': 249,
#   'y1': 152,
#   'x2': 284,
#   'y2': 195,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/36.jpg',
#   'x1': 202,
#   'y1': 337,
#   'x2': 345,
#   'y2': 371,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/36.jpg',
#   'x1': 214,
#   'y1': 405,
#   'x2': 370,
#   'y2': 434,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/37.jpg',
#   'x1': 221,
#   'y1': 210,
#   'x2': 304,
#   'y2': 244,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/37.jpg',
#   'x1': 146,
#   'y1': 491,
#   'x2': 345,
#   'y2': 538,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/38.jpg',
#   'x1': 89,
#   'y1': 413,
#   'x2': 383,
#   'y2': 498,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/38.jpg',
#   'x1': 202,
#   'y1': 188,
#   'x2': 283,
#   'y2': 215,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/39.jpg',
#   'x1': 172,
#   'y1': 321,
#   'x2': 308,
#   'y2': 375,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/39.jpg',
#   'x1': 190,
#   'y1': 148,
#   'x2': 264,
#   'y2': 173,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/39.jpg',
#   'x1': 149,
#   'y1': 392,
#   'x2': 318,
#   'y2': 444,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/40.jpg',
#   'x1': 259,
#   'y1': 70,
#   'x2': 370,
#   'y2': 96,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/40.jpg',
#   'x1': 168,
#   'y1': 287,
#   'x2': 450,
#   'y2': 373,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/41.jpg',
#   'x1': 270,
#   'y1': 191,
#   'x2': 312,
#   'y2': 228,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/41.jpg',
#   'x1': 221,
#   'y1': 369,
#   'x2': 323,
#   'y2': 420,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/41.jpg',
#   'x1': 215,
#   'y1': 443,
#   'x2': 372,
#   'y2': 475,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/42.jpg',
#   'x1': 311,
#   'y1': 120,
#   'x2': 364,
#   'y2': 148,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/42.jpg',
#   'x1': 280,
#   'y1': 277,
#   'x2': 405,
#   'y2': 311,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/42.jpg',
#   'x1': 255,
#   'y1': 323,
#   'x2': 406,
#   'y2': 359,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/43.jpg',
#   'x1': 184,
#   'y1': 22,
#   'x2': 268,
#   'y2': 47,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/43.jpg',
#   'x1': 121,
#   'y1': 285,
#   'x2': 289,
#   'y2': 334,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/43.jpg',
#   'x1': 115,
#   'y1': 365,
#   'x2': 322,
#   'y2': 430,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/44.jpg',
#   'x1': 227,
#   'y1': 144,
#   'x2': 265,
#   'y2': 161,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/44.jpg',
#   'x1': 210,
#   'y1': 250,
#   'x2': 289,
#   'y2': 281,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/44.jpg',
#   'x1': 195,
#   'y1': 290,
#   'x2': 295,
#   'y2': 319,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/45.jpg',
#   'x1': 153,
#   'y1': 371,
#   'x2': 319,
#   'y2': 414,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/45.jpg',
#   'x1': 256,
#   'y1': 184,
#   'x2': 296,
#   'y2': 213,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/45.jpg',
#   'x1': 144,
#   'y1': 417,
#   'x2': 330,
#   'y2': 469,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/46.jpg',
#   'x1': 490,
#   'y1': 65,
#   'x2': 562,
#   'y2': 96,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/46.jpg',
#   'x1': 465,
#   'y1': 253,
#   'x2': 616,
#   'y2': 293,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/46.jpg',
#   'x1': 435,
#   'y1': 353,
#   'x2': 639,
#   'y2': 403,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/47.jpg',
#   'x1': 149,
#   'y1': 116,
#   'x2': 216,
#   'y2': 132,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/47.jpg',
#   'x1': 114,
#   'y1': 266,
#   'x2': 262,
#   'y2': 300,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/47.jpg',
#   'x1': 108,
#   'y1': 308,
#   'x2': 271,
#   'y2': 340,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/48.jpg',
#   'x1': 305,
#   'y1': 139,
#   'x2': 370,
#   'y2': 166,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/48.jpg',
#   'x1': 268,
#   'y1': 296,
#   'x2': 405,
#   'y2': 339,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/48.jpg',
#   'x1': 247,
#   'y1': 350,
#   'x2': 416,
#   'y2': 379,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/49.jpg',
#   'x1': 180,
#   'y1': 230,
#   'x2': 290,
#   'y2': 266,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/49.jpg',
#   'x1': 74,
#   'y1': 548,
#   'x2': 374,
#   'y2': 626,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/50.jpg',
#   'x1': 170,
#   'y1': 261,
#   'x2': 295,
#   'y2': 282,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/50.jpg',
#   'x1': 159,
#   'y1': 297,
#   'x2': 304,
#   'y2': 320,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/50.jpg',
#   'x1': 236,
#   'y1': 133,
#   'x2': 268,
#   'y2': 143,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/51.jpg',
#   'x1': 230,
#   'y1': 121,
#   'x2': 282,
#   'y2': 146,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/51.jpg',
#   'x1': 165,
#   'y1': 287,
#   'x2': 312,
#   'y2': 321,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/51.jpg',
#   'x1': 152,
#   'y1': 334,
#   'x2': 314,
#   'y2': 379,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/52.jpg',
#   'x1': 196,
#   'y1': 164,
#   'x2': 266,
#   'y2': 192,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/52.jpg',
#   'x1': 137,
#   'y1': 401,
#   'x2': 328,
#   'y2': 452,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/52.jpg',
#   'x1': 125,
#   'y1': 480,
#   'x2': 339,
#   'y2': 530,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/53.jpg',
#   'x1': 173,
#   'y1': 167,
#   'x2': 255,
#   'y2': 195,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/53.jpg',
#   'x1': 111,
#   'y1': 410,
#   'x2': 321,
#   'y2': 466,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/53.jpg',
#   'x1': 89,
#   'y1': 499,
#   'x2': 346,
#   'y2': 552,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/54.jpg',
#   'x1': 234,
#   'y1': 128,
#   'x2': 281,
#   'y2': 146,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/54.jpg',
#   'x1': 201,
#   'y1': 257,
#   'x2': 314,
#   'y2': 295,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/54.jpg',
#   'x1': 188,
#   'y1': 300,
#   'x2': 327,
#   'y2': 330,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/55.jpg',
#   'x1': 201,
#   'y1': 201,
#   'x2': 267,
#   'y2': 222,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/55.jpg',
#   'x1': 143,
#   'y1': 396,
#   'x2': 330,
#   'y2': 443,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/55.jpg',
#   'x1': 127,
#   'y1': 467,
#   'x2': 357,
#   'y2': 507,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/56.jpg',
#   'x1': 321,
#   'y1': 53,
#   'x2': 399,
#   'y2': 110,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/56.jpg',
#   'x1': 214,
#   'y1': 380,
#   'x2': 435,
#   'y2': 436,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/57.jpg',
#   'x1': 172,
#   'y1': 153,
#   'x2': 249,
#   'y2': 187,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/57.jpg',
#   'x1': 94,
#   'y1': 377,
#   'x2': 279,
#   'y2': 420,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/57.jpg',
#   'x1': 87,
#   'y1': 442,
#   'x2': 294,
#   'y2': 483,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/58.jpg',
#   'x1': 307,
#   'y1': 191,
#   'x2': 366,
#   'y2': 211,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/58.jpg',
#   'x1': 236,
#   'y1': 388,
#   'x2': 407,
#   'y2': 438,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/59.jpg',
#   'x1': 299,
#   'y1': 167,
#   'x2': 367,
#   'y2': 192,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/59.jpg',
#   'x1': 256,
#   'y1': 355,
#   'x2': 398,
#   'y2': 408,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/59.jpg',
#   'x1': 225,
#   'y1': 429,
#   'x2': 408,
#   'y2': 479,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/60.jpg',
#   'x1': 197,
#   'y1': 161,
#   'x2': 277,
#   'y2': 188,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/60.jpg',
#   'x1': 141,
#   'y1': 413,
#   'x2': 325,
#   'y2': 462,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/60.jpg',
#   'x1': 115,
#   'y1': 482,
#   'x2': 334,
#   'y2': 536,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/61.jpg',
#   'x1': 206,
#   'y1': 143,
#   'x2': 276,
#   'y2': 177,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/61.jpg',
#   'x1': 144,
#   'y1': 358,
#   'x2': 309,
#   'y2': 411,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/61.jpg',
#   'x1': 103,
#   'y1': 434,
#   'x2': 326,
#   'y2': 491,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/62.jpg',
#   'x1': 312,
#   'y1': 117,
#   'x2': 363,
#   'y2': 141,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/62.jpg',
#   'x1': 281,
#   'y1': 278,
#   'x2': 406,
#   'y2': 312,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/62.jpg',
#   'x1': 256,
#   'y1': 326,
#   'x2': 410,
#   'y2': 369,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/63.jpg',
#   'x1': 306,
#   'y1': 153,
#   'x2': 368,
#   'y2': 179,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/63.jpg',
#   'x1': 242,
#   'y1': 355,
#   'x2': 406,
#   'y2': 400,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 395,
#   'y1': 308,
#   'x2': 521,
#   'y2': 339,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 251,
#   'y1': 285,
#   'x2': 386,
#   'y2': 321,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 136,
#   'y1': 273,
#   'x2': 245,
#   'y2': 304,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 7,
#   'y1': 304,
#   'x2': 145,
#   'y2': 341,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 5,
#   'y1': 356,
#   'x2': 128,
#   'y2': 380,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 131,
#   'y1': 314,
#   'x2': 250,
#   'y2': 345,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/64.jpg',
#   'x1': 386,
#   'y1': 345,
#   'x2': 521,
#   'y2': 364,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 351,
#   'y1': 279,
#   'x2': 421,
#   'y2': 307,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 374,
#   'y1': 173,
#   'x2': 401,
#   'y2': 188,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 347,
#   'y1': 315,
#   'x2': 437,
#   'y2': 338,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 142,
#   'y1': 264,
#   'x2': 194,
#   'y2': 285,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 156,
#   'y1': 169,
#   'x2': 180,
#   'y2': 181,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/65.jpg',
#   'x1': 142,
#   'y1': 288,
#   'x2': 201,
#   'y2': 309,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/66.jpg',
#   'x1': 232,
#   'y1': 305,
#   'x2': 377,
#   'y2': 347,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/66.jpg',
#   'x1': 219,
#   'y1': 376,
#   'x2': 393,
#   'y2': 416,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/67.jpg',
#   'x1': 318,
#   'y1': 97,
#   'x2': 371,
#   'y2': 134,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/67.jpg',
#   'x1': 248,
#   'y1': 337,
#   'x2': 413,
#   'y2': 376,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/67.jpg',
#   'x1': 234,
#   'y1': 386,
#   'x2': 429,
#   'y2': 417,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/68.jpg',
#   'x1': 279,
#   'y1': 110,
#   'x2': 353,
#   'y2': 141,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/68.jpg',
#   'x1': 221,
#   'y1': 311,
#   'x2': 373,
#   'y2': 340,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/68.jpg',
#   'x1': 211,
#   'y1': 386,
#   'x2': 381,
#   'y2': 429,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/69.jpg',
#   'x1': 161,
#   'y1': 400,
#   'x2': 318,
#   'y2': 444,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/69.jpg',
#   'x1': 136,
#   'y1': 505,
#   'x2': 339,
#   'y2': 546,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/69.jpg',
#   'x1': 190,
#   'y1': 171,
#   'x2': 269,
#   'y2': 187,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/70.jpg',
#   'x1': 251,
#   'y1': 161,
#   'x2': 310,
#   'y2': 192,
#   'body_part': 'neck'},
#  {'file_name': './dataset/clean_resized/70.jpg',
#   'x1': 173,
#   'y1': 376,
#   'x2': 317,
#   'y2': 415,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/70.jpg',
#   'x1': 150,
#   'y1': 440,
#   'x2': 326,
#   'y2': 482,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/71.jpg',
#   'x1': 84,
#   'y1': 392,
#   'x2': 266,
#   'y2': 422,
#   'body_part': 'stomach'},
#  {'file_name': './dataset/clean_resized/71.jpg',
#   'x1': 77,
#   'y1': 482,
#   'x2': 274,
#   'y2': 527,
#   'body_part': 'hip'},
#  {'file_name': './dataset/clean_resized/71.jpg',
#   'x1': 111,
#   'y1': 163,
#   'x2': 199,
#   'y2': 195,
#   'body_part': 'neck'}]

# %%
from dataloader import CocoDataset, CSVDataset, collater, Resizer, AspectRatioBasedSampler, Augmenter, UnNormalizer, Normalizer
from torch.utils.data import Dataset, DataLoader
dataset_train = CSVDataset(train_file='./csv_annotations.csv', class_list='./classes.csv', transform=transforms.Compose([Normalizer(), Augmenter(), Resizer()]))
